# %%
from requests_oauthlib import OAuth1Session
import requests
import json

# %%
# Informamos as chaves criadas pelo Twitter
CHAVE_CONSUMO =	'Oe1bOe3sKJw012exE1KOqywIz'
TOKEN_CONSUMO =	'eSkNi7PcGNzCzDA5x3SIIQb4GdSQh52NS8Xd2KCmwjhi1VQXyD'

TOKEN_ACESSO =	'172973614-IOOCgpm4w1C45da1PlXBcRJxB9SQ9fnjsjwzIuUl'
CHAVE_ACESSO =	'xtESJ5giSo0034MEeqkj5JTr25ZOUOTTArirIWStaiYIg'

# %%
session = OAuth1Session (CHAVE_CONSUMO, TOKEN_CONSUMO, TOKEN_ACESSO, CHAVE_ACESSO)

# %%
# Vamos criar uma função para busca dos tweets
def BuscaTweets(query):
    url_busca = "https://api.twitter.com/1.1/search/tweets.json"
    url = url_busca + "?q=%s&lang=pt&count=100"
    url = url % (requests.utils.quote(query))
    response = session.get(url)
    return response.content

# %%
# Vamos buscar os tweets primeiros em portugues 100 tweets que falam sobre um assunto
resposta = BuscaTweets('suruba do doria')

# %%
tweets = json.loads(resposta)

# %%
tweets
# Out:
# {'statuses': [{'created_at': 'Tue May 07 23:35:41 +0000 2019',
#    'id': 1125907081603710976,
#    'id_str': '1125907081603710976',
#    'text': '@robertabastosn Ou pior, no Doria... \nTodos midíaticos.. ainda romantizará a suruba do governador...',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'robertabastosn',
#       'name': 'Roberta Bastos',
#       'id': 875072728088399872,
#       'id_str': '875072728088399872',
#       'indices': [0, 15]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1125903181769314304,
#    'in_reply_to_status_id_str': '1125903181769314304',
#    'in_reply_to_user_id': 875072728088399872,
#    'in_reply_to_user_id_str': '875072728088399872',
#    'in_reply_to_screen_name': 'robertabastosn',
#    'user': {'id': 60936376,
#     'id_str': '60936376',
#     'name': 'Nina',
#     'screen_name': 'papel_em_branco',
#     'location': 'Brazil',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3655,
#     'friends_count': 2794,
#     'listed_count': 6,
#     'created_at': 'Tue Jul 28 15:42:49 +0000 2009',
#     'favourites_count': 27408,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 15337,
#     'lang': 'pt',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '5F3863',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1113457366840819712/4sgJPmmO_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1113457366840819712/4sgJPmmO_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/60936376/1546479214',
#     'profile_link_color': 'DB99CE',
#     'profile_sidebar_border_color': '5C1B5C',
#     'profile_sidebar_fill_color': '252429',
#     'profile_text_color': 'A31010',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 4,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'pt'},
#   {'created_at': 'Tue May 07 13:19:44 +0000 2019',
#    'id': 1125752072836718592,
#    'id_str': '1125752072836718592',
#    'text': 'RT @kepler_johann: @UOLNoticias 🎵Dória, rainha do Frevo e do Maracatu\nNinguém pratica Suruba\nPior do que tu...🎶',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'kepler_johann',
#       'name': 'Kepler & Kopernikus🔭',
#       'id': 773610639591895041,
#       'id_str': '773610639591895041',
#       'indices': [3, 17]},
#      {'screen_name': 'UOLNoticias',
#       'name': 'UOL Notícias',
#       'id': 14594698,
#       'id_str': '14594698',
#       'indices': [19, 31]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2538053700,
#     'id_str': '2538053700',
#     'name': '#LulaLivreQuartaSDV',
#     'screen_name': 'ElaineG16',
#     'location': '',
#     'description': 'Astronauta. Já fui a lua duas vezes e voltei.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 13794,
#     'friends_count': 11454,
#     'listed_count': 286,
#     'created_at': 'Sat May 31 19:14:07 +0000 2014',
#     'favourites_count': 118564,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 249270,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1116705835198091265/_PLCxdX8_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1116705835198091265/_PLCxdX8_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2538053700/1552796811',
#     'profile_link_color': 'E81C4F',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Mon May 06 21:52:33 +0000 2019',
#     'id': 1125518738713976832,
#     'id_str': '1125518738713976832',
#     'text': '@UOLNoticias 🎵Dória, rainha do Frevo e do Maracatu\nNinguém pratica Suruba\nPior do que tu...🎶',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'UOLNoticias',
#        'name': 'UOL Notícias',
#        'id': 14594698,
#        'id_str': '14594698',
#        'indices': [0, 12]}],
#      'urls': []},
#     'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': 1125487126487998464,
#     'in_reply_to_status_id_str': '1125487126487998464',
#     'in_reply_to_user_id': 14594698,
#     'in_reply_to_user_id_str': '14594698',
#     'in_reply_to_screen_name': 'UOLNoticias',
#     'user': {'id': 773610639591895041,
#      'id_str': '773610639591895041',
#      'name': 'Kepler & Kopernikus🔭',
#      'screen_name': 'kepler_johann',
#      'location': 'São Paulo, Brasil',
#      'description': 'Engenheiro Eletricista. Ateu, amante da Física e da Astronomia. Esquerda Esturjão e palmeirense ⚽\nReligion poisons everything',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 11844,
#      'friends_count': 5348,
#      'listed_count': 42,
#      'created_at': 'Wed Sep 07 19:55:24 +0000 2016',
#      'favourites_count': 65488,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 70682,
#      'lang': 'pt',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1119343896629272576/vOUNSGXR_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1119343896629272576/vOUNSGXR_normal.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/773610639591895041/1533319949',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': {'id': '68e019afec7d0ba5',
#      'url': 'https://api.twitter.com/1.1/geo/id/68e019afec7d0ba5.json',
#      'place_type': 'city',
#      'name': 'Sao Paulo',
#      'full_name': 'Sao Paulo, Brazil',
#      'country_code': 'BR',
#      'country': 'Brazil',
#      'contained_within': [],
#      'bounding_box': {'type': 'Polygon',
#       'coordinates': [[[-46.826039, -24.008814],
#         [-46.365052, -24.008814],
#         [-46.365052, -23.356792],
#         [-46.826039, -23.356792]]]},
#      'attributes': {}},
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 4,
#     'favorite_count': 24,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'pt'},
#    'is_quote_status': False,
#    'retweet_count': 4,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'pt'},
#   {'created_at': 'Tue May 07 10:38:15 +0000 2019',
#    'id': 1125711433205940224,
#    'id_str': '1125711433205940224',
#    'text': 'RT @kepler_johann: @UOLNoticias 🎵Dória, rainha do Frevo e do Maracatu\nNinguém pratica Suruba\nPior do que tu...🎶',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'kepler_johann',
#       'name': 'Kepler & Kopernikus🔭',
#       'id': 773610639591895041,
#       'id_str': '773610639591895041',
#       'indices': [3, 17]},
#      {'screen_name': 'UOLNoticias',
#       'name': 'UOL Notícias',
#       'id': 14594698,
#       'id_str': '14594698',
#       'indices': [19, 31]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 268909716,
#     'id_str': '268909716',
#     'name': 'Claudia Santos',
#     'screen_name': 'molleeccuullaa',
#     'location': 'São Paulo',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 234,
#     'friends_count': 538,
#     'listed_count': 0,
#     'created_at': 'Sat Mar 19 18:30:46 +0000 2011',
#     'favourites_count': 35344,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 12922,
#     'lang': 'es',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1047903294599905280/MTO331dm_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1047903294599905280/MTO331dm_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/268909716/1489180143',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Mon May 06 21:52:33 +0000 2019',
#     'id': 1125518738713976832,
#     'id_str': '1125518738713976832',
#     'text': '@UOLNoticias 🎵Dória, rainha do Frevo e do Maracatu\nNinguém pratica Suruba\nPior do que tu...🎶',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'UOLNoticias',
#        'name': 'UOL Notícias',
#        'id': 14594698,
#        'id_str': '14594698',
#        'indices': [0, 12]}],
#      'urls': []},
#     'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': 1125487126487998464,
#     'in_reply_to_status_id_str': '1125487126487998464',
#     'in_reply_to_user_id': 14594698,
#     'in_reply_to_user_id_str': '14594698',
#     'in_reply_to_screen_name': 'UOLNoticias',
#     'user': {'id': 773610639591895041,
#      'id_str': '773610639591895041',
#      'name': 'Kepler & Kopernikus🔭',
#      'screen_name': 'kepler_johann',
#      'location': 'São Paulo, Brasil',
#      'description': 'Engenheiro Eletricista. Ateu, amante da Física e da Astronomia. Esquerda Esturjão e palmeirense ⚽\nReligion poisons everything',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 11844,
#      'friends_count': 5348,
#      'listed_count': 42,
#      'created_at': 'Wed Sep 07 19:55:24 +0000 2016',
#      'favourites_count': 65488,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 70682,
#      'lang': 'pt',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1119343896629272576/vOUNSGXR_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1119343896629272576/vOUNSGXR_normal.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/773610639591895041/1533319949',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': {'id': '68e019afec7d0ba5',
#      'url': 'https://api.twitter.com/1.1/geo/id/68e019afec7d0ba5.json',
#      'place_type': 'city',
#      'name': 'Sao Paulo',
#      'full_name': 'Sao Paulo, Brazil',
#      'country_code': 'BR',
#      'country': 'Brazil',
#      'contained_within': [],
#      'bounding_box': {'type': 'Polygon',
#       'coordinates': [[[-46.826039, -24.008814],
#         [-46.365052, -24.008814],
#         [-46.365052, -23.356792],
#         [-46.826039, -23.356792]]]},
#      'attributes': {}},
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 4,
#     'favorite_count': 24,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'pt'},
#    'is_quote_status': False,
#    'retweet_count': 4,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'pt'},
#   {'created_at': 'Tue May 07 01:57:57 +0000 2019',
#    'id': 1125580495331504128,
#    'id_str': '1125580495331504128',
#    'text': 'RT @kepler_johann: @UOLNoticias 🎵Dória, rainha do Frevo e do Maracatu\nNinguém pratica Suruba\nPior do que tu...🎶',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'kepler_johann',
#       'name': 'Kepler & Kopernikus🔭',
#       'id': 773610639591895041,
#       'id_str': '773610639591895041',
#       'indices': [3, 17]},
#      {'screen_name': 'UOLNoticias',
#       'name': 'UOL Notícias',
#       'id': 14594698,
#       'id_str': '14594698',
#       'indices': [19, 31]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 917493692,
#     'id_str': '917493692',
#     'name': 'Mário Silvio',
#     'screen_name': 'mario_mrsilvio',
#     'location': 'Amazonas, Brasil',
#     'description': 'Bolsonaro é o caralho. Lula livre, porra!',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 441,
#     'friends_count': 629,
#     'listed_count': 1,
#     'created_at': 'Wed Oct 31 19:16:49 +0000 2012',
#     'favourites_count': 31044,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 11942,
#     'lang': 'pt',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'EBEBEB',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme7/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme7/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/934942851821129728/DrT5U0QC_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/934942851821129728/DrT5U0QC_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/917493692/1557280289',
#     'profile_link_color': '990000',
#     'profile_sidebar_border_color': 'DFDFDF',
#     'profile_sidebar_fill_color': 'F3F3F3',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Mon May 06 21:52:33 +0000 2019',
#     'id': 1125518738713976832,
#     'id_str': '1125518738713976832',
#     'text': '@UOLNoticias 🎵Dória, rainha do Frevo e do Maracatu\nNinguém pratica Suruba\nPior do que tu...🎶',
#     'truncated': False,
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'UOLNoticias',
#        'name': 'UOL Notícias',
#        'id': 14594698,
#        'id_str': '14594698',
#        'indices': [0, 12]}],
#      'urls': []},
#     'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'in_reply_to_status_id': 1125487126487998464,
#     'in_reply_to_status_id_str': '1125487126487998464',
#     'in_reply_to_user_id': 14594698,
#     'in_reply_to_user_id_str': '14594698',
#     'in_reply_to_screen_name': 'UOLNoticias',
#     'user': {'id': 773610639591895041,
#      'id_str': '773610639591895041',
#      'name': 'Kepler & Kopernikus🔭',
#      'screen_name': 'kepler_johann',
#      'location': 'São Paulo, Brasil',
#      'description': 'Engenheiro Eletricista. Ateu, amante da Física e da Astronomia. Esquerda Esturjão e palmeirense ⚽\nReligion poisons everything',
#      'url': None,
#      'entities': {'description': {'urls': []}},
#      'protected': False,
#      'followers_count': 11844,
#      'friends_count': 5348,
#      'listed_count': 42,
#      'created_at': 'Wed Sep 07 19:55:24 +0000 2016',
#      'favourites_count': 65488,
#      'utc_offset': None,
#      'time_zone': None,
#      'geo_enabled': True,
#      'verified': False,
#      'statuses_count': 70682,
#      'lang': 'pt',
#      'contributors_enabled': False,
#      'is_translator': False,
#      'is_translation_enabled': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1119343896629272576/vOUNSGXR_normal.png',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1119343896629272576/vOUNSGXR_normal.png',
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/773610639591895041/1533319949',
#      'profile_link_color': '1B95E0',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'has_extended_profile': True,
#      'default_profile': False,
#      'default_profile_image': False,
#      'following': False,
#      'follow_request_sent': False,
#      'notifications': False,
#      'translator_type': 'none'},
#     'geo': None,
#     'coordinates': None,
#     'place': {'id': '68e019afec7d0ba5',
#      'url': 'https://api.twitter.com/1.1/geo/id/68e019afec7d0ba5.json',
#      'place_type': 'city',
#      'name': 'Sao Paulo',
#      'full_name': 'Sao Paulo, Brazil',
#      'country_code': 'BR',
#      'country': 'Brazil',
#      'contained_within': [],
#      'bounding_box': {'type': 'Polygon',
#       'coordinates': [[[-46.826039, -24.008814],
#         [-46.365052, -24.008814],
#         [-46.365052, -23.356792],
#         [-46.826039, -23.356792]]]},
#      'attributes': {}},
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 4,
#     'favorite_count': 24,
#     'favorited': False,
#     'retweeted': False,
#     'lang': 'pt'},
#    'is_quote_status': False,
#    'retweet_count': 4,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'pt'},
#   {'created_at': 'Mon May 06 21:52:33 +0000 2019',
#    'id': 1125518738713976832,
#    'id_str': '1125518738713976832',
#    'text': '@UOLNoticias 🎵Dória, rainha do Frevo e do Maracatu\nNinguém pratica Suruba\nPior do que tu...🎶',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'UOLNoticias',
#       'name': 'UOL Notícias',
#       'id': 14594698,
#       'id_str': '14594698',
#       'indices': [0, 12]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1125487126487998464,
#    'in_reply_to_status_id_str': '1125487126487998464',
#    'in_reply_to_user_id': 14594698,
#    'in_reply_to_user_id_str': '14594698',
#    'in_reply_to_screen_name': 'UOLNoticias',
#    'user': {'id': 773610639591895041,
#     'id_str': '773610639591895041',
#     'name': 'Kepler & Kopernikus🔭',
#     'screen_name': 'kepler_johann',
#     'location': 'São Paulo, Brasil',
#     'description': 'Engenheiro Eletricista. Ateu, amante da Física e da Astronomia. Esquerda Esturjão e palmeirense ⚽\nReligion poisons everything',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 11844,
#     'friends_count': 5348,
#     'listed_count': 42,
#     'created_at': 'Wed Sep 07 19:55:24 +0000 2016',
#     'favourites_count': 65488,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 70682,
#     'lang': 'pt',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1119343896629272576/vOUNSGXR_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1119343896629272576/vOUNSGXR_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/773610639591895041/1533319949',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': {'id': '68e019afec7d0ba5',
#     'url': 'https://api.twitter.com/1.1/geo/id/68e019afec7d0ba5.json',
#     'place_type': 'city',
#     'name': 'Sao Paulo',
#     'full_name': 'Sao Paulo, Brazil',
#     'country_code': 'BR',
#     'country': 'Brazil',
#     'contained_within': [],
#     'bounding_box': {'type': 'Polygon',
#      'coordinates': [[[-46.826039, -24.008814],
#        [-46.365052, -24.008814],
#        [-46.365052, -23.356792],
#        [-46.826039, -23.356792]]]},
#     'attributes': {}},
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 4,
#    'favorite_count': 24,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'pt'},
#   {'created_at': 'Sat May 04 17:33:06 +0000 2019',
#    'id': 1124728672387305473,
#    'id_str': '1124728672387305473',
#    'text': '@g1 A culpa dessa facçao é do psdb que fez acordo com pcc,joao doria suruba de pau mole tem que mudar isso',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'g1',
#       'name': 'G1',
#       'id': 8802752,
#       'id_str': '8802752',
#       'indices': [0, 3]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'in_reply_to_status_id': 1124683850607579136,
#    'in_reply_to_status_id_str': '1124683850607579136',
#    'in_reply_to_user_id': 8802752,
#    'in_reply_to_user_id_str': '8802752',
#    'in_reply_to_screen_name': 'g1',
#    'user': {'id': 117178100,
#     'id_str': '117178100',
#     'name': 'vgrs',
#     'screen_name': 'betorsvg',
#     'location': 'sao paulo',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 71,
#     'friends_count': 1690,
#     'listed_count': 0,
#     'created_at': 'Wed Feb 24 19:55:09 +0000 2010',
#     'favourites_count': 154,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 4249,
#     'lang': 'pt',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C6E2EE',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme2/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme2/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/502322075789705216/ZSflaqbA_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/502322075789705216/ZSflaqbA_normal.jpeg',
#     'profile_link_color': '1F98C7',
#     'profile_sidebar_border_color': 'C6E2EE',
#     'profile_sidebar_fill_color': 'DAECF4',
#     'profile_text_color': '663B12',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'pt'},
#   {'created_at': 'Sat May 04 01:15:26 +0000 2019',
#    'id': 1124482633117913089,
#    'id_str': '1124482633117913089',
#    'text': '@neglignt as pessoas parecem tao empogadas nessa suruba, acho que to até vendo o doria ali do lado',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'neglignt',
#       'name': 'lusca',
#       'id': 2602470111,
#       'id_str': '2602470111',
#       'indices': [0, 9]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1124453569820876803,
#    'in_reply_to_status_id_str': '1124453569820876803',
#    'in_reply_to_user_id': 2602470111,
#    'in_reply_to_user_id_str': '2602470111',
#    'in_reply_to_screen_name': 'neglignt',
#    'user': {'id': 4024418781,
#     'id_str': '4024418781',
#     'name': 'cymko',
#     'screen_name': 'mimi_ladyy',
#     'location': 'São Paulo, Brasil',
#     'description': '',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 20,
#     'friends_count': 29,
#     'listed_count': 0,
#     'created_at': 'Fri Oct 23 13:34:45 +0000 2015',
#     'favourites_count': 152,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 253,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1048442855260393472/c948xywZ_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1048442855260393472/c948xywZ_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4024418781/1531863758',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 2,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'pt'},
#   {'created_at': 'Fri May 03 11:03:04 +0000 2019',
#    'id': 1124268130791038977,
#    'id_str': '1124268130791038977',
#    'text': '@calulabarros Nojo dos eleitores do meu interior, não é a toa q somos governados por essa trupe quadrilheiros desde… https://t.co/BVIKNI0Lz7',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'calulabarros',
#       'name': 'Carol Lula Barros',
#       'id': 115135583,
#       'id_str': '115135583',
#       'indices': [0, 13]}],
#     'urls': [{'url': 'https://t.co/BVIKNI0Lz7',
#       'expanded_url': 'https://twitter.com/i/web/status/1124268130791038977',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1123908921494777856,
#    'in_reply_to_status_id_str': '1123908921494777856',
#    'in_reply_to_user_id': 115135583,
#    'in_reply_to_user_id_str': '115135583',
#    'in_reply_to_screen_name': 'calulabarros',
#    'user': {'id': 357164452,
#     'id_str': '357164452',
#     'name': 'Júnior Pereira',
#     'screen_name': 'AntnioPereiraJr',
#     'location': 'Guapiaçu SP',
#     'description': 'Santos sempre Santos',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 207,
#     'friends_count': 712,
#     'listed_count': 0,
#     'created_at': 'Wed Aug 17 23:19:10 +0000 2011',
#     'favourites_count': 917,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1681,
#     'lang': 'pt',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1500950526/Imagem_525_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1500950526/Imagem_525_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/357164452/1533173967',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'pt'},
#   {'created_at': 'Wed May 01 00:50:13 +0000 2019',
#    'id': 1123389122708692994,
#    'id_str': '1123389122708692994',
#    'text': 'Tô mais cansado do q o pau do Dória na suruba #/poeteiro #/exausto — tadinho do nene:( https://t.co/RIC4bAjw03',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/RIC4bAjw03',
#       'expanded_url': 'https://curiouscat.me/favmots/post/863584297?t=1556671812',
#       'display_url': 'curiouscat.me/favmots/post/8…',
#       'indices': [87, 110]}]},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="https://curiouscat.me" rel="nofollow">Curious Cat</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 804507723530457088,
#     'id_str': '804507723530457088',
#     'name': 'millary d-17',
#     'screen_name': 'favmots',
#     'location': 'lore.rhi.lu.ka.mi.ranya.jessie',
#     'description': 'bts, seventeen, mamamoo, skz, day6, astro, blockb, suzy, hyuna. [kdrama]. larissa♥️',
#     'url': 'https://t.co/oDTUfeaRvW',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/oDTUfeaRvW',
#         'expanded_url': 'http://curiouscat.me/favmots',
#         'display_url': 'curiouscat.me/favmots',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1797,
#     'friends_count': 1696,
#     'listed_count': 8,
#     'created_at': 'Fri Dec 02 02:09:23 +0000 2016',
#     'favourites_count': 2406,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 3655,
#     'lang': 'pt',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1125696422114934785/RJsSZixH_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1125696422114934785/RJsSZixH_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/804507723530457088/1557197841',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'pt'},
#   {'created_at': 'Tue Apr 30 04:02:27 +0000 2019',
#    'id': 1123075115397386240,
#    'id_str': '1123075115397386240',
#    'text': '@jpegke Ele tem muito a cara do Doria, neh. O que me faz pensar que ele deve curtir uma suruba também.',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'jpegke',
#       'name': 'jorge ben jor',
#       'id': 598564758,
#       'id_str': '598564758',
#       'indices': [0, 7]}],
#     'urls': []},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1123073558605914114,
#    'in_reply_to_status_id_str': '1123073558605914114',
#    'in_reply_to_user_id': 598564758,
#    'in_reply_to_user_id_str': '598564758',
#    'in_reply_to_screen_name': 'jpegke',
#    'user': {'id': 1081519349486243841,
#     'id_str': '1081519349486243841',
#     'name': 'Ciro do Deboche 🌹',
#     'screen_name': 'CiroGames22',
#     'location': 'URSAL, Ai Dentu',
#     'description': 'A democracia é uma delicia, mas tem seus custos. (Ciro Ferreira Gomes)',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 517,
#     'friends_count': 1219,
#     'listed_count': 0,
#     'created_at': 'Sat Jan 05 11:54:41 +0000 2019',
#     'favourites_count': 7218,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 3088,
#     'lang': 'pt',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1105224302671118337/ib1I_mfN_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1105224302671118337/ib1I_mfN_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1081519349486243841/1555216306',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 1,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'pt'},
#   {'created_at': 'Tue Apr 30 03:39:26 +0000 2019',
#    'id': 1123069322606403584,
#    'id_str': '1123069322606403584',
#    'text': '@BrancoMG @JornalOGlobo Aí  fala merda!  E  o surubão  de Rondonópolis? Só  com rapazes  tradicionais de direita,… https://t.co/76EPZt6ytZ',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'BrancoMG',
#       'name': 'João Branco 🇧🇷🇮🇱🇺🇸',
#       'id': 1040034400367534080,
#       'id_str': '1040034400367534080',
#       'indices': [0, 9]},
#      {'screen_name': 'JornalOGlobo',
#       'name': 'Jornal O Globo',
#       'id': 54341363,
#       'id_str': '54341363',
#       'indices': [10, 23]}],
#     'urls': [{'url': 'https://t.co/76EPZt6ytZ',
#       'expanded_url': 'https://twitter.com/i/web/status/1123069322606403584',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [115, 138]}]},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': 1122992070489247746,
#    'in_reply_to_status_id_str': '1122992070489247746',
#    'in_reply_to_user_id': 1040034400367534080,
#    'in_reply_to_user_id_str': '1040034400367534080',
#    'in_reply_to_screen_name': 'BrancoMG',
#    'user': {'id': 734971720709382144,
#     'id_str': '734971720709382144',
#     'name': 'mila queiroz👩👩\u200d👧\u200d👧👨\u200d👧',
#     'screen_name': 'milaqueirozzzzz',
#     'location': '🇧🇷',
#     'description': '💐🤗✊💪🕊🌬',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 58,
#     'friends_count': 131,
#     'listed_count': 0,
#     'created_at': 'Tue May 24 04:58:08 +0000 2016',
#     'favourites_count': 312,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 1117,
#     'lang': 'pt',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1103380928737488899/xW0ArgFK_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1103380928737488899/xW0ArgFK_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/734971720709382144/1551901488',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 0,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'pt'}],
#  'search_metadata': {'completed_in': 0.061,
#   'max_id': 1125907081603710976,
#   'max_id_str': '1125907081603710976',
#   'next_results': '?max_id=1123069322606403583&q=suruba%20do%20doria&lang=pt&count=100&include_entities=1',
#   'query': 'suruba+do+doria',
#   'refresh_url': '?since_id=1125907081603710976&q=suruba%20do%20doria&lang=pt&include_entities=1',
#   'count': 100,
#   'since_id': 0,
#   'since_id_str': '0'}}

# %%
# Verifica os campos retornados pelo Twitter
print(tweets['statuses'][0].keys())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-57-326636ccfd77> in <module>
#       1 # Verifica os campos retornados pelo Twitter
# ----> 2 print(tweets['statuses'][0].keys())
#
# IndexError: list index out of range

# %%
# Percorre a lista de tweets e formata a saída
for t in tweets["statuses"]:
        print (t["user"]["screen_name"] + " - " + t["text"])
# Out:
# anchisesbr - Hoje palestro no INOVAE/FMU 2019: 'Fintechs e os desafios da segurança' https://t.co/p8MwKaXKNr
# xvhbs - Só porque eu queria muito participar do Inovae da facul, não vou poder por causa do atestado :(
# zaynpologetic - do que me adianta ter uma semana sem aula na faculdade se eu tenho dois artigos p terminar de escrever e ainda tenh… https://t.co/NH2XyiIZiK
# thenewvini - Acho que agora posso ir dormir mais tranquilo, muito feliz que deu certo a apresentação no Inovae
# _ferroLu - um agradecimento ao inovae por me dar uma semana sem aula
# _Caqueiroz_ - Amém semana do INOVAE
# japaruivx - obg inovae por me deixar 1 semana sem aula 🥰
# pztlucas - nossa acabei de lembrar que é a semana do inovae e não tem aula
# whoisreolon - ansiosa para caralho para apresentar meu Projeto no inovae

# %%
# Busca os próximos 100 tweets
url2 = url_original + tweets["search_metadata"]["next_results"]
response2 = session.get(url2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-8853461fc0d1> in <module>
#       1 # Busca os próximos 100 tweets
# ----> 2 url2 = url_original + tweets["search_metadata"]["next_results"]
#       3 response2 = session.get(url2)
#
# NameError: name 'url_original' is not defined

# %%
tweets2 = json.loads(response2.content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-6c431ecd1ac1> in <module>
# ----> 1 tweets2 = json.loads(response2.content)
#
# NameError: name 'response2' is not defined

# %%
for t in tweets2["statuses"]:
        print (t["user"]["screen_name"] + " - " + t["text"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-99176a0f65b2> in <module>
# ----> 1 for t in tweets2["statuses"]:
#       2         print (t["user"]["screen_name"] + " - " + t["text"])
#
# NameError: name 'tweets2' is not defined

# %%
# Vamos criar agora uma função para buscar os perfis
def BuscaPerfil(perfil):
    url = "https://api.twitter.com/1.1/users/show.json?screen_name=" + perfil
    response = session.get(url)
    return response.content

# %%
# Vamos buscar um perfil
respostaPerfil = BuscaPerfil('realDonaldTrump')
# Captura o perfil do usuário
perfil = json.loads(respostaPerfil)

# %%
# Exibe o perfil
perfil
# Out:
# {'id': 25073877,
#  'id_str': '25073877',
#  'name': 'Donald J. Trump',
#  'screen_name': 'realDonaldTrump',
#  'location': 'Washington, DC',
#  'profile_location': None,
#  'description': '45th President of the United States of America🇺🇸',
#  'url': 'https://t.co/OMxB0x7xC5',
#  'entities': {'url': {'urls': [{'url': 'https://t.co/OMxB0x7xC5',
#      'expanded_url': 'http://www.Instagram.com/realDonaldTrump',
#      'display_url': 'Instagram.com/realDonaldTrump',
#      'indices': [0, 23]}]},
#   'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 60105275,
#  'friends_count': 46,
#  'listed_count': 102648,
#  'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#  'favourites_count': 7,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'verified': True,
#  'statuses_count': 41702,
#  'lang': 'en',
#  'status': {'created_at': 'Wed May 08 23:32:51 +0000 2019',
#   'id': 1126268756257382400,
#   'id_str': '1126268756257382400',
#   'text': 'Big crowds in Panama City Beach, Florida. See everyone in 30 minutes! @FoxNews @TuckerCarlson @SeanHannity https://t.co/57tngL1W2i',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'FoxNews',
#      'name': 'Fox News',
#      'id': 1367531,
#      'id_str': '1367531',
#      'indices': [70, 78]},
#     {'screen_name': 'TuckerCarlson',
#      'name': 'Tucker Carlson',
#      'id': 22703645,
#      'id_str': '22703645',
#      'indices': [79, 93]},
#     {'screen_name': 'seanhannity',
#      'name': 'Sean Hannity',
#      'id': 41634520,
#      'id_str': '41634520',
#      'indices': [94, 106]}],
#    'urls': [],
#    'media': [{'id': 1126268696933150720,
#      'id_str': '1126268696933150720',
#      'indices': [107, 130],
#      'media_url': 'http://pbs.twimg.com/media/D6FPaaJXsAAtBJ9.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/D6FPaaJXsAAtBJ9.jpg',
#      'url': 'https://t.co/57tngL1W2i',
#      'display_url': 'pic.twitter.com/57tngL1W2i',
#      'expanded_url': 'https://twitter.com/realDonaldTrump/status/1126268756257382400/photo/1',
#      'type': 'photo',
#      'sizes': {'small': {'w': 680, 'h': 244, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 1024, 'h': 368, 'resize': 'fit'},
#       'medium': {'w': 1024, 'h': 368, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1126268696933150720,
#      'id_str': '1126268696933150720',
#      'indices': [107, 130],
#      'media_url': 'http://pbs.twimg.com/media/D6FPaaJXsAAtBJ9.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/D6FPaaJXsAAtBJ9.jpg',
#      'url': 'https://t.co/57tngL1W2i',
#      'display_url': 'pic.twitter.com/57tngL1W2i',
#      'expanded_url': 'https://twitter.com/realDonaldTrump/status/1126268756257382400/photo/1',
#      'type': 'photo',
#      'sizes': {'small': {'w': 680, 'h': 244, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 1024, 'h': 368, 'resize': 'fit'},
#       'medium': {'w': 1024, 'h': 368, 'resize': 'fit'}}}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 2108,
#   'favorite_count': 7020,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  'contributors_enabled': False,
#  'is_translator': False,
#  'is_translation_enabled': True,
#  'profile_background_color': '6D5C18',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': True,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1557167376',
#  'profile_link_color': '1B95E0',
#  'profile_sidebar_border_color': 'BDDCAD',
#  'profile_sidebar_fill_color': 'C5CEC0',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'has_extended_profile': False,
#  'default_profile': False,
#  'default_profile_image': False,
#  'following': False,
#  'follow_request_sent': False,
#  'notifications': False,
#  'translator_type': 'regular'}

# %%
# Formatando a saída
print ("Nome:" + perfil["name"])
print ("Perfil: @" + perfil["screen_name"])
print ("Cidade: " + perfil["location"])
print ("Descrição: " + perfil["description"])
print ("Seguindo: " + str(perfil["friends_count"]))
print("Seguidores: " + str(perfil["followers_count"]))
# Out:
# Nome:Donald J. Trump
# Perfil: @realDonaldTrump
# Cidade: Washington, DC
# Descrição: 45th President of the United States of America🇺🇸
# Seguindo: 46
# Seguidores: 60105275
